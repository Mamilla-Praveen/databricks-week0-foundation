# %% [markdown]
# ### Creating tables and inserting values

# %%
# %sql
drop table employees

# %%
# %sql

CREATE TABLE employees (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
manager_id INT,
dept_id INT
);
INSERT INTO employees (emp_id, emp_name, manager_id, dept_id) VALUES
(1, 'Karthik', NULL, 1),
(2, 'Ajay', 1, 1),
(3, 'Vijay', 1, 2),
(4, 'Vinay', 2, 2),
(5, 'Meena', 3, 3),
(6, 'Veer', NULL, 4),
(7, 'Keerthi', 4, 5),
(8, 'Priya', 4, 5);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

# %%
# %sql
select * from employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>manager_id</th><th>dept_id</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>null</td><td>1</td></tr><tr><td>2</td><td>Ajay</td><td>1</td><td>1</td></tr><tr><td>3</td><td>Vijay</td><td>1</td><td>2</td></tr><tr><td>4</td><td>Vinay</td><td>2</td><td>2</td></tr><tr><td>5</td><td>Meena</td><td>3</td><td>3</td></tr><tr><td>6</td><td>Veer</td><td>null</td><td>4</td></tr><tr><td>7</td><td>Keerthi</td><td>4</td><td>5</td></tr><tr><td>8</td><td>Priya</td><td>4</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
CREATE TABLE departments (
dept_id INT PRIMARY KEY,
dept_name VARCHAR(50)
);

INSERT INTO departments (dept_id, dept_name) VALUES
(1, 'HR'),
(2, 'IT'),
(3, 'Finance'),
(4, 'Marketing'),
(5, 'Sales');

CREATE TABLE projects (
project_id INT PRIMARY KEY,
project_name VARCHAR(50),
emp_id INT
);

# %%
# %sql
INSERT INTO projects (project_id, project_name, emp_id) VALUES
(1, 'Project A', 1),
(2, 'Project B', 2),
(3, 'Project C', 3),
(4, 'Project D', 4),
(5, 'Project E', 5);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %% [markdown]
# ##Retrieve the names of employees and their corresponding managers from the employees" table, ensuring that even employees without managers are included.

# %%
# %sql
SELECT e.emp_name AS employee_name,
       m.emp_name AS manager_name
FROM employees e
LEFT JOIN employees m
ON e.manager_id = m.emp_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_name</th><th>manager_name</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td></tr><tr><td>Ajay</td><td>Karthik</td></tr><tr><td>Vijay</td><td>Karthik</td></tr><tr><td>Vinay</td><td>Ajay</td></tr><tr><td>Meena</td><td>Vijay</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>Vinay</td></tr><tr><td>Priya</td><td>Vinay</td></tr></tbody></table></div>

# %% [markdown]
# ### . Display all employees and their corresponding departments from the "employees" and "departments" tables, showing employees even if they don't belong to any department.

# %%
# %sql
select emp_name,dept_name from employees left join departments 
on employees.dept_id = departments.dept_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

# %% [markdown]
# ### 5. Display a list of employees who do not belong to any department, even if the department data is missing.

# %%
# %sql
select emp_name from employees
where dept_id is null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### 6. Fetch the names of employees and the projects they are assigned to. For employees who are not assigned any projects, show NULL for the project.

# %%
# %sql
select emp_name,project_id,project_name from employees
left join projects
on employees.emp_id = projects.emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_id</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>1</td><td>Project A</td></tr><tr><td>Ajay</td><td>2</td><td>Project B</td></tr><tr><td>Vijay</td><td>3</td><td>Project C</td></tr><tr><td>Vinay</td><td>4</td><td>Project D</td></tr><tr><td>Meena</td><td>5</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td><td>null</td></tr><tr><td>Priya</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ### 7. List all employees who have completed at least one project, showing their names and the project names.

# %%
# %sql
select employees.emp_id,employees.emp_name,count(projects.project_id) from employees join projects on employees.emp_id = projects.emp_id
group by employees.emp_id,employees.emp_name,projects.project_name
having count(projects.project_id) >= 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>count(projects.project_id)</th></tr></thead><tbody><tr><td>3</td><td>Vijay</td><td>1</td></tr><tr><td>2</td><td>Ajay</td><td>1</td></tr><tr><td>5</td><td>Meena</td><td>1</td></tr><tr><td>1</td><td>Karthik</td><td>1</td></tr><tr><td>4</td><td>Vinay</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ### 8. Show the names of employees and their projects, ensuring that no project is omitted even if an employee is not assigned to it.

# %%
# %sql
select emp_name,project_name from employees left join projects
on employees.emp_id = projects.emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>
